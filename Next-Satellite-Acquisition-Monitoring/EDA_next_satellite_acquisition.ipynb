# %% [markdown]
#  <img width="20%" alt="EarthDaily Analytics" src="https://raw.githubusercontent.com/earthdaily/Images/main/Corporate/EarthDaily.png" style="border-radius: 15%">
#
# <!-- <img width="20%" alt="EarthDaily Agro" src="https://raw.githubusercontent.com/earthdaily/Images/main/Corporate/EarthDaily_Agro.png"  style="border-radius: 15%"> -->

# %% [markdown]
# # EDAgro - Public Satellite Acquisitions & Cloud Cover
# <a href="https://earthdaily.com/contact/">Give Feedback</a> | <a href="https://github.com/earthdaily">Bug report</a>

# %% [markdown]
# **Tags:** #EDS #machinelearning #cloudcover #timeseries #satellites #sentinel2 #landsat

# %% [markdown]
# **Author:** [EarthDaily](mailto:sales@earthdailyagro.com)

# %% [markdown]
# **Last update:** 2025-02-27 (Created: 2025-02-20)

# %% [markdown]
# **Description:** Next satellite acquisition highlighting how Earthdaily supports their clients to anticipate next clear satellite image

# %% [markdown]
# **References:**
# - [EarthSpectator](https://spectator.earth/) to access next public satellite acquisitions
# - [EarthDaily](https://github.com/earthdaily/earthdaily-python-client) for examples using EarthDaily capabilities
# - [Sentinel-2 Grid](https://github.com/maawoo/sentinel-2-grid-geoparquet/tree/main) to access Sentinel-2 grid online

# %% [markdown]
# #### Introduction
# ____
# Anticipation of coverage is key to manage a PrecisionAg service. With this script, EarthDaily clients have a quick and easy to use tool to get the right information over their area of interest.

# %% [markdown]
# #### Objectives
# ____
# - The goal of this notebook is to anticipate next clear satellite image thanks to the combinaison of public satellite acquisition plans and cloud cover data.
# - Data Acquisition: Public satellite acquisition plans and cloud cover data from EarthDaily API
# - Visualization: One map per constellation of satellite and per day with the percentage of cloud cover on the center of the Sentinel-2 tile.
# - Data Export: Map are exported in html files. For other formats, please contact us, we will update this notebook.
# - Adaptability: Users and change the clip_wkt parameter by their area of interest

# %% [markdown]
# #### Data Description
# ____
# - Public Satellite Acquisitions Passes comes from EarthSpectator which get the information from ESA and USGS.
# - Sentinel-2 Tiles Grid comes from an online URL from ESA
# - Cloud cover data comes from EarthDaily Weather Hub API

# %% [markdown]
# ## 1️⃣ Input
#
# - We start by setting up the environment and loading the necessary libraries.
# - We then load Environment Variables: Access API keys and other configurations.
# - To authenticate and Initialize Client: Connect to the data source for querying and retrieving the data.
# - And we finally declare Global Variables: Such as the input Collection, a list of Bands, output Resolution, Bounding Box or geometry to clip to...

# %% [markdown]
# ### Import dependencies

# %%
import os.path as pa
import sys
import os
from os import listdir
from os.path import isfile, join
import requests
import requests.exceptions as rex
import pandas as pd
import geopandas as gpd
import numpy as np
import getpass
import json
import datetime as dt
from dateutil.relativedelta import relativedelta
import random
import shapefile
from shapely import wkt
from shapely.wkt import loads
from shapely.geometry import box
import folium
from pathlib import Path
import re
from IPython.display import display
from dotenv import load_dotenv

# %% [markdown]
# ### URL

# %%
identity_urls = {
    'preprod': 'https://identity.preprod.geosys-na.com/v2.1/connect/token',
    'prod': 'https://identity.geosys-na.com/v2.1/connect/token'
}
eda_data_management_url = {
    'preprod': 'https://api-pp.geosys-na.net/master-data-management/v6/seasonfields',
    'prod': 'https://api.geosys-na.net/master-data-management/v6/seasonfields'
}
map_products_urls = {
    'preprod': 'http://api-pp.geosys-na.net/field-level-maps/v5',
    'prod': 'http://api.geosys-na.net/field-level-maps/v5'
}
map_products_urls_old = {
    'preprod': 'http://api-pp.geosys-na.net/field-level-maps/v4',
    'prod': 'http://api.geosys-na.net/field-level-maps/v4'
}

# %% [markdown]
# ### Define your path - working directory

# %%
# define your path - working directory
path='***'

# %% [markdown]
# ### Authentication

# %% [markdown]
# ##### Earth Spectator authentication

# %%
# EarthSpectator API credentials
api_key_earth_spectator = '***'

# %% [markdown]
# ##### Default cells for edagro authentication

# %%
# Option 1 - Set credentials
env = "prod"
api_username = '***'
api_password = '***'
api_client_id = '***'
api_client_secret = '***'

# %%
# Option 2 - Load env file
load_dotenv()
env = os.getenv('ENVIRONMENT')
api_client_id = os.getenv('API_CLIENT_ID')
api_client_secret = os.getenv('API_CLIENT_SECRET')
api_username = os.getenv('API_USERNAME')
api_password = os.getenv('API_PASSWORD')

# %%
# Authentication token
response=requests.post(identity_urls[env], data={'grant_type':'password','scope':'openid',
                         'username':api_username,'password':api_password},
                          headers={'Authorization':'Basic c3dhZ2dlcjpzd2FnZ2VyLnNlY3JldA==',
                             'Accept':'application/json, text/plain, */*',
                             'Content-Type':'application/x-www-form-urlencoded'})
result=response.json()
bearer_token=result['access_token']

# %% [markdown]
# ⚠️ This token access is available during one hour. Once the hour has passed, recall the authentication API to get another token access.

# %% [markdown]
# ### Setup Variables

# %%
# URL to access S2 Grid
URL_ESA_S2_GRID_KML = "https://sentinel.esa.int/documents/247904/1955685/S2A_OPER_GIP_TILPAR_MPC__20151209T095117_V20150622T000000_21000101T000000_B00.kml"
URL_NE_VEC_10m_LAND_GEOJSON = "https://github.com/nvkelso/natural-earth-vector/raw/v5.1.2/geojson/ne_10m_land.geojson"

# %% [markdown]
# ## 2️⃣ Model

# %% [markdown]
# ### Functions

# %% [markdown]
# #### From https://github.com/maawoo/sentinel-2-grid-geoparquet/tree/main

# %%
def get_esa_s2_grid_kml(url: str = URL_ESA_S2_GRID_KML) -> Path | None:
    """
    Download the ESA S2 grid KML file to the current working directory.
    
    Parameters
    ----------
    url : str
        URL to the ESA S2 grid KML file.
    
    Returns
    -------
    out : pathlib.Path or None
        Path to the downloaded file if successful, otherwise None.
    """
    out = Path.cwd() / url.split("/")[-1]
    if out.exists():
        print(f"{out.name} already exists; skip downloading.")
        return out
    
    response = requests.get(url)
    if response.status_code == 200:
        with open(out, 'wb') as file:
            file.write(response.content)
        print(f"Downloaded {out.name} to {out.parent}")
        return out
    else:
        print(f"Failed to download {url}")
        print(f"Status code & reason: {response.status_code} / {response.reason}")
        return None

# %%
def get_utm_wkt(row: pd.Series) -> str:
    """
    Extract UTM WKT from the description of the ESA S2 grid KML file.
    
    Parameters
    ----------
    row : pandas.Series
        A row of the ESA S2 grid KML file.
    
    Returns
    -------
    utm_wkt : str
        UTM WKT string.
    """
    text = row.description.split('<b>')[-2]
    m = re.findall('MULTIPOLYGON\(\(\((.+?)\)\)\)', text)
    utm_wkt = f"POLYGON (({m[0]}))"
    return utm_wkt
# Out:
# <>:16: SyntaxWarning: invalid escape sequence '\('
# <>:16: SyntaxWarning: invalid escape sequence '\('
# C:\Users\mal\AppData\Local\Temp\ipykernel_1124\73025121.py:16: SyntaxWarning: invalid escape sequence '\('
#   m = re.findall('MULTIPOLYGON\(\(\((.+?)\)\)\)', text)

# %%
def get_epsg(row: pd.Series) -> int:
    """
    Extract EPSG code from the description of the ESA S2 grid KML file.
    
    Parameters
    ----------
    row : pandas.Series
        A row of the ESA S2 grid KML file.

    Returns
    -------
    epsg : int
        EPSG code.
    """
    text = row.description.split('<b>')[2]
    m = re.findall('<font COLOR="#008000">(.+?)</font>', text)
    epsg = int(m[0])
    return epsg

# %% [markdown]
# ### Import clip geometry

# %%
# Import geometry to work on 
clip_wkt = "POLYGON ((-0.791016 54.800685, -1.538086 55.652798, -4.174805 54.72462, -4.790039 53.435719, -5.229492 51.808615, -5.668945 49.979488, -1.186523 50.569283, 1.494141 51.124213, 2.241211 52.402419, -0.791016 54.800685))" # UK AOI

# %% [markdown]
# ### Data processing

# %% [markdown]
# #### Load KML file directly from URL

# %%
# Load KML file directly from URL
gdf = gpd.read_file(URL_ESA_S2_GRID_KML, 
                    engine="pyogrio", force_2d=True, 
                    columns=["Name", "geometry"])
gdf.rename(columns=dict(Name='tile'), inplace=True)
gdf.head()
# Out:
#     tile                                           geometry
# 0  01CCV  GEOMETRYCOLLECTION (POLYGON ((180 -73.05974, 1...
# 1  01CDH  GEOMETRYCOLLECTION (POLYGON ((180 -83.80855, 1...
# 2  01CDJ  GEOMETRYCOLLECTION (POLYGON ((180 -82.91344, 1...
# 3  01CDK  GEOMETRYCOLLECTION (POLYGON ((180 -82.01866, 1...
# 4  01CDL  GEOMETRYCOLLECTION (POLYGON ((180 -81.12317, 1...

# %% [markdown]
# #### Clip S2 tiles grid by geometry

# %%
# Convert WKT string to a Shapely geometry
clip_geometry = wkt.loads(clip_wkt)

# Convert to a GeoDataFrame
clip_gdf = gpd.GeoDataFrame(geometry=[clip_geometry], crs=gdf.crs)

# Ensure CRS consistency
if gdf.crs != clip_gdf.crs:
    clip_gdf = clip_gdf.to_crs(gdf.crs)
    
# Perform clipping
clipped_gdf = gpd.clip(gdf, clip_gdf)

# Compute centroids
clipped_gdf["centroid"] = clipped_gdf.geometry.centroid

# Perform clipping and reset index
clipped_gdf = clipped_gdf.reset_index(drop=True)

print(len(clipped_gdf))

# Display results
print(clipped_gdf[["geometry", "centroid"]])
# Out:
# 44
#                                              geometry  \
# 0   POLYGON ((-0.12428 51.4159, 1.45059 51.3666, 1...
# 1   POLYGON ((0.12371 51.41588, 1.68082 51.44362, ...
# 2   POLYGON ((1.56055 51.44235, 1.68047 51.44301, ...
# 3   POLYGON ((-0.06638 52.31404, 1.53998 52.26314,...
# 4   POLYGON ((0.0658 52.31402, 1.67592 52.34305, 1...
# 5   POLYGON ((1.53153 52.34135, 2.20773 52.34514, ...
# 6   POLYGON ((-0.00536 53.21199, 1.26931 53.17112,...
# 7   POLYGON ((0.00476 53.21198, 1.19031 53.23361, ...
# 8   POLYGON ((2.15618 52.25693, 1.53443 52.25345, ...
# 9   POLYGON ((0.05898 54.10922, 0.08427 54.1084, 1...
# 10  POLYGON ((-0.05959 54.10921, 0.07999 54.11178,...
# 11  POLYGON ((0.18859 54.02589, -0.05314 54.02143,...
# 12  POLYGON ((-5.54425 50.49849, -4.63426 50.47036...
# 13  POLYGON ((-1.58865 50.54374, -1.40663 50.54032...
# 14  POLYGON ((-3.00028 50.55229, -1.45067 50.54198...
# 15  POLYGON ((-4.41191 50.54373, -2.86223 50.55221...
# 16  POLYGON ((-1.56112 51.44235, 0.01703 51.41234,...
# 17  POLYGON ((-3.00029 51.45118, -1.42046 51.44054...
# 18  POLYGON ((-4.43945 51.44235, -2.85954 51.4511,...
# 19  POLYGON ((-5.53835 50.52308, -4.27308 50.54533...
# 20  POLYGON ((-5.32982 51.39103, -4.54941 51.3666,...
# 21  POLYGON ((-5.32147 51.42577, -4.29791 51.444, ...
# 22  POLYGON ((-5.10125 52.28346, -4.46002 52.26314...
# 23  POLYGON ((-5.08887 52.32926, -4.32408 52.34305...
# 24  POLYGON ((-1.53212 52.34136, 0.07776 52.31037,...
# 25  POLYGON ((-3.00029 52.35047, -1.38862 52.33948...
# 26  POLYGON ((-4.46847 52.34135, -2.85671 52.35039...
# 27  POLYGON ((-1.50154 53.24021, 0.14177 53.2082, ...
# 28  POLYGON ((-3.0003 53.24963, -1.35505 53.23828,...
# 29  POLYGON ((-4.49906 53.2402, -2.85372 53.24954,...
# 30  POLYGON ((-1.4693 54.13837, 0.08509 54.10775, ...
# 31  POLYGON ((-4.86038 53.17528, -4.36582 53.15942...
# 32  POLYGON ((-4.8448 53.23297, -4.35166 53.24196,...
# 33  POLYGON ((-4.491 54.06219, -4.26651 54.05491, ...
# 34  POLYGON ((-4.45442 54.13883, -4.38074 54.14019...
# 35  POLYGON ((-4.38569 54.28282, -4.37783 54.05231...
# 36  POLYGON ((-3.00031 54.1481, -1.31966 54.13638,...
# 37  POLYGON ((-4.45443 54.13881, -2.85057 54.14801...
# 38  POLYGON ((-1.43523 55.03693, -0.99037 55.02807...
# 39  POLYGON ((-3.00031 55.04699, -1.28227 55.03487...
# 40  POLYGON ((-3.26622 55.04446, -2.84725 55.04689...
# 41  POLYGON ((-0.91192 54.93859, -1.43864 54.94907...
# 42  POLYGON ((-1.26853 55.34534, -1.28601 54.94702...
# 43  POLYGON ((-2.84667 55.19215, -2.84758 54.959, ...
#
#                      centroid
# 0    POINT (0.53517 51.15882)
# 1     POINT (0.7902 51.20681)
# 2     POINT (1.6025 51.37778)
# 3    POINT (0.69653 51.79783)
# 4     POINT (0.89153 51.8384)
# 5    POINT (1.77039 51.98456)
# 6    POINT (0.74996 52.68359)
# 7    POINT (0.81356 52.71406)
# 8    POINT (1.79375 52.50982)
# 9    POINT (0.47836 53.44309)
# 10   POINT (0.41924 53.49219)
# 11    POINT (0.0222 54.09228)
# 12  POINT (-5.15734 50.26092)
# 13  POINT (-1.52824 50.53344)
# 14  POINT (-2.46694 50.47478)
# 15  POINT (-3.71758 50.39222)
# 16  POINT (-0.84598 51.03568)
# 17  POINT (-2.22752 50.96134)
# 18   POINT (-3.6427 50.95485)
# 19  POINT (-4.97325 50.29675)
# 20  POINT (-5.02406 50.87389)
# 21  POINT (-4.86443 50.92128)
# 22  POINT (-4.87236 51.76518)
# 23  POINT (-4.76753 51.81579)
# 24  POINT (-0.75171 51.83447)
# 25  POINT (-2.20316 51.85326)
# 26  POINT (-3.65543 51.85413)
# 27  POINT (-0.70574 52.73296)
# 28  POINT (-2.18685 52.75237)
# 29  POINT (-3.66885 52.75327)
# 30  POINT (-0.66012 53.62922)
# 31   POINT (-4.7093 52.65368)
# 32  POINT (-4.66225 52.70446)
# 33  POINT (-4.53227 53.50706)
# 34   POINT (-4.54849 53.5236)
# 35  POINT (-4.42009 54.12842)
# 36   POINT (-2.16966 53.6508)
# 37   POINT (-3.6801 53.65019)
# 38   POINT (-0.8808 54.43071)
# 39   POINT (-2.1515 54.54963)
# 40    POINT (-3.5369 54.4833)
# 41  POINT (-1.25554 55.13376)
# 42  POINT (-1.99488 55.20602)
# 43  POINT (-3.07143 55.03542)
# C:\Users\mal\AppData\Local\Temp\ipykernel_1124\4076151674.py:15: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   clipped_gdf["centroid"] = clipped_gdf.geometry.centroid

# %% [markdown]
# #### Call Earth Spectator API

# %%
# Call Earth Spectator API to get next satellites passes 

response=[]
Sat_date=[]
satellites='Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9' #list of satellites - can be modified Sentinel-1A
for z in range(len(clipped_gdf)):
    geometry = clipped_gdf["geometry"][z]
    get_sat_url = "https://api.spectator.earth/overpass/?api_key="+api_key_earth_spectator+"&satellites="+satellites+"&geometry="+str(geometry)+"&days_before=0&days_after=9"
    print(get_sat_url)
    response = requests.request("GET", get_sat_url)
    print(response)
    res_sat=response.json()

    for j in range(len(res_sat["overpasses"])):    
        if (res_sat != []):
            data_res={}
            data_res["geometry"]=clipped_gdf["geometry"][z]
            data_res["centroid"]=clipped_gdf["centroid"][z]
            data_res["date"]=res_sat["overpasses"][j]["date"]
            data_res["satellite"]=res_sat["overpasses"][j]["satellite"]
            data_res["acquisition"]=res_sat["overpasses"][j]["footprints"]["features"][0]["properties"]["acquisition"]
            Sat_date.append(data_res)

# Export in CSV
output_file = pd.DataFrame(columns=['geometry','centroid','date','satellite', 'acquisition']) # create a Dataframe to save the results
output_file=[]

for k in range(len(Sat_date)):
        output_file.append({'geometry':Sat_date[k]['geometry'],
                            'centroid':Sat_date[k]["centroid"],
                            'date':Sat_date[k]["date"],
                            'satellite':Sat_date[k]["satellite"],
                            'acquisition':Sat_date[k]["acquisition"],
                                    })       

output_file=pd.DataFrame(output_file)

# Save results in csv
output_file.to_csv(pa.join(path,'sat_passes.csv'),sep=';',index=False)

# remove satellite passes without acquisitionn
data=pd.read_csv(path +"/sat_passes.csv",sep=';', names = ['geometry', 'centroid', 'date', 'satellite', 'acquisition'], header = 0, dtype = {'acquisition': str})       
indexNames = data[data['acquisition'] != str('True') ].index
data.drop(indexNames, inplace=True)
# Out:
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-0.1242827114 51.41589769590001, 1.450589699 51.3666020113, 1.4263753311990919 51.11018468366207, -0.1630345184036801 50.781157544177205, -0.1242827114 51.41589769590001))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((0.1237082317 51.415883589, 1.6808235001556402 51.443619068767234, 1.494141 51.124213, 0.1584036402540807 50.847699146326505, 0.1237082317 51.415883589))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((1.5605478501 51.4423452524, 1.6804672944571863 51.44300961548843, 1.5664888166101787 51.24799713438905, 1.5605478501 51.4423452524))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-0.0663842342 52.31403780419999, 1.5399796808 52.26313739659999, 1.4420951843 51.2789251815, -0.1297842359 51.3280673107, -0.0663842342 52.31403780419999))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((0.0657982283 52.3140232376, 1.6759245503 52.3430543844, 1.7010331522276283 51.478196951075894, 1.6288724694830958 51.35473299502337, 0.1292108515 51.3280532478, 0.0657982283 52.3140232376))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((1.5315289026 52.3413478024, 2.207733185732978 52.34513983865904, 1.6289089189513333 51.35479535856226, 1.5633051206 51.3544323479, 1.5315289026 52.3413478024))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-0.0053590772 53.2119928713, 1.2693086827064448 53.17112143648855, 1.6073779994759112 52.903733754744586, 1.5310321704 52.1754847178, -0.0721799686 52.2262253907, -0.0053590772 53.2119928713))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((0.0047609251 53.2119778261, 1.1903055063679107 53.23360707219613, 1.6599664485638892 52.862140203390936, 1.678544065 52.2551507483, 0.0715951164 52.2262108699, 0.0047609251 53.2119778261))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((2.156178614749687 52.25693209111427, 1.5344338485 52.2534495347, 1.5097399199144657 52.980958212714754, 2.241211 52.402419, 2.156178614749687 52.25693209111427))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((0.058982728 54.10922199150001, 0.0842661260920389 54.10840194750616, 1.3859025265442797 53.07890437903025, -0.0115077056 53.12366003370001, 0.058982728 54.10922199150001))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-0.0595936833 54.1092064475, 0.0799922465331263 54.11178226831797, 1.2996420653558536 53.147129987209496, 0.0109107771 53.1236450364, -0.0595936833 54.1092064475))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((0.1885936458668778 54.025886639931784, -0.0531424252 54.0214307105, -0.0688655533852145 54.22951771503055, 0.1885936458668778 54.025886639931784))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-5.544253905664104 50.4984874090593, -4.6342572365 50.4703606298, -4.666471643908035 50.111392977500174, -5.668945 49.979488, -5.544253905664104 50.4984874090593))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-1.588650494 50.5437391738, -1.406631632499573 50.54032120860573, -1.5894481828216953 50.5162662920233, -1.588650494 50.5437391738))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-3.0002823155 50.5522921101, -1.4506718533 50.5419848176, -1.4509105797226534 50.53449500534387, -3.0002810279527385 50.33062956306426, -3.0002823155 50.5522921101))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-4.4119138634 50.5437323314, -2.8622302442 50.5522106218, -2.862807061078934 50.34871832362548, -4.400372687417333 50.146406154314725, -4.4119138634 50.5437323314))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-1.5611232056 51.4423523164, 0.0170250085 51.4123426545, -0.0215254129996359 50.810451647377704, -1.186523 50.569283, -1.5894210158365338 50.51626986664256, -1.5611232056 51.4423523164))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-3.0002878241 51.4511822053, -1.4204559785 51.4405411653, -1.4508472411122046 50.534503339408744, -2.0368443262394713 50.457398115754515, -3.0002817883 50.4637984013, -3.0002878241 51.4511822053))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-4.4394521499 51.4423452524, -2.8595420423 51.4510980778, -2.8624875052 50.4637171673, -4.4092784144 50.4552653391, -4.4394521499 51.4423452524))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-5.5383460326680485 50.52307763829805, -4.273075584 50.5453331581, -4.2631002492521235 50.16446839782228, -5.668945 49.979488, -5.5383460326680485 50.52307763829805))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-5.329818027566827 51.39102985249793, -4.549410301 51.3666020113, -4.6423781018 50.3821222498, -5.565365623889395 50.410614499277656, -5.329818027566827 51.39102985249793))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-5.321472549495001 51.42576607973744, -4.2979078728 51.4439979075, -4.2706991082 50.45686117010001, -5.559695085513266 50.43421687506827, -5.321472549495001 51.42576607973744))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-5.101245630276636 52.28345572508861, -4.4600203192 52.26313739659999, -4.5579048157 51.2789251815, -5.350796013887902 51.303713572519165, -5.229492 51.808615, -5.101245630276636 52.28345572508861))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-5.0888733795613055 52.329264807352054, -4.3240754497 52.3430543844, -4.2954215353 51.3560798434, -5.342691129379959 51.33744838166909, -5.229492 51.808615, -5.0888733795613055 52.329264807352054))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-1.5321158471 52.34135509680001, 0.0777579253 52.3103669144, 0.0112541226 51.3245233542, -1.5638793749 51.35443938980001, -1.5321158471 52.34135509680001))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-3.0002936291 52.3504731569, -1.3886156372 52.3394848517, -1.4234813358 51.3526338928, -3.0002872726 51.36324170729999, -3.0002936291 52.3504731569))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-4.4684710974 52.3413478024, -2.8567092332 52.35038628320001, -2.8598112014 51.3631578425, -4.4366948794 51.3544323479, -4.4684710974 52.3413478024))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-1.5015395717 53.240208349, 0.1417699045 53.2082013722, 0.071678487 52.222566033, -1.5350196328 52.2534568061, -1.5015395717 53.240208349))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-3.0002997482 53.2496264673, -1.3550533354 53.2382765736, -1.3918030116 52.2515924439, -3.000293048 52.2625461785, -3.0002997482 53.2496264673))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-4.4990595879 53.2402008146, -2.8537231276 53.2495367341, -2.8569928153 52.2624595782, -4.4655661515 52.2534495347, -4.4990595879 53.2402008146))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-1.4692987436 54.1383733178, 0.0850890592794922 54.10775106857007, 0.2024771412057118 54.01490582786452, 0.1353203692 53.11988062130001, -1.5046204185 53.1517854981, -1.4692987436 54.1383733178))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-4.860379180310908 53.17527979775402, -4.3658169826 53.15942196619999, -4.4689678296 52.1754847178, -5.124800723576802 52.19624142337928, -4.860379180310908 53.17527979775402))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-4.844798954528108 53.2329666213554, -4.3516584855 53.2419635471, -4.321455935 52.2551507483, -5.112739106254627 52.240900364816426, -4.844798954528108 53.2329666213554))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-4.491003190133041 54.06219210514915, -4.2665096284 54.05491086089999, -4.3753078425 53.0712565273, -4.884073217726938 53.087551046202044, -4.790039 53.435719, -4.491003190133041 54.06219210514915))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-4.454422815206104 54.13882714453856, -4.3807432794 54.14018677499999, -4.3488792292 53.1535350929, -4.868811056768267 53.14406021360902, -4.790039 53.435719, -4.454422815206104 54.13882714453856))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-4.385690823099121 54.282819078272205, -4.3778275361 54.0523118483, -4.496765855684686 54.05011945410552, -4.385690823099121 54.282819078272205))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-3.0003062006 54.1481041035, -1.3196641317 54.13637742820001, -1.3584350438 53.1498598892, -3.0002991317 53.1611735443, -3.0003062006 54.1481041035))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-4.454432547151785 54.13880675633745, -2.8505743708 54.1480113907, -2.8540240095 53.1610840978, -4.4959775103 53.1517779877, -4.525961957378542 53.98895429634552, -4.454432547151785 54.13880675633745))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-1.4352272877 55.0369285873, -0.9903681247178311 55.0280673564722, -0.791016 54.800685, 0.1990591774957352 54.01760918290847, -1.4725308705 54.05050420129999, -1.4352272877 55.0369285873))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-3.0003130196 55.0469860315, -1.2822657732 55.03486571650001, -1.3232118719 54.0485147058, -3.0003055538 54.0602038042, -3.0003130196 55.0469860315))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-3.266223065885885 55.04445907365258, -2.8472467263 55.0468902056, -2.8508900363 54.06011138859999, -4.496499489614747 54.05067748486115, -4.174805 54.72462, -3.266223065885885 55.04445907365258))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-0.9119239000409638 54.93859335320332, -1.4386425575 54.9490740098, -1.4160669363159948 55.51362224617108, -0.9119239000409638 54.93859335320332))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-1.2685294999409944 55.34534006709575, -1.2860145154 54.9470178194, -3.0003123361 54.95909887389999, -3.0003137679184255 55.13806448263581, -1.538086 55.652798, -1.2685294999409944 55.34534006709575))&days_before=0&days_after=9
# <Response [200]>
# https://api.spectator.earth/overpass/?api_key=SDMmWhwvaaRtHhJoPk9KGP&satellites=Sentinel-2A,Sentinel-2B,Sentinel-2C,Landsat-8,Landsat-9&geometry=POLYGON ((-2.846670030211575 55.192150161533434, -2.847580289000001 54.95900335849999, -3.5200541846053888 54.95510542614186, -2.846670030211575 55.192150161533434))&days_before=0&days_after=9
# <Response [200]>

# %% [markdown]
# #### change date time format

# %%
# change date time format       
date_final = pd.to_datetime(data.date)
data['date'] = date_final.dt.strftime('%Y-%m-%d')
change_hour = date_final.dt.strftime('%H:%M:%S')
change_hour_h = date_final.dt.strftime('%H')
data.insert(3, "hour", change_hour, allow_duplicates=False)
data.insert(3, "h", change_hour_h, allow_duplicates=False)

date_final = pd.to_datetime(data.date)
colonne_date = data['date']+"T"+ data['h'] 
col_date = pd.to_datetime(colonne_date)
date_good =pd.to_datetime(col_date).dt.strftime('%Y-%m-%dT%H:%M:%S.0000000Z')
data.insert(3, "iso", date_good, allow_duplicates=False)

# Remove columns
df = pd.DataFrame(data)
df = df.drop(['h'], axis=1)

# Save results in csv
df.to_csv(pa.join(path,'sat_passes_final.csv'),sep=';',index=False)
#df

# %% [markdown]
# #### Call EarthDaily Agro WeatherHub API

# %%
# Get cloud cover data through EarthDaily WeatherHub API

data=pd.read_csv(path +"/sat_passes_final.csv",sep=';', names = ['location', 'GPS', 'date','iso','hour','satellite', 'acquisition'], header = 0)
response=[]
Image_date=[]
start=dt.date.today()

for i in range(len(data)):
               
    get_coverage_url = "https://api.geosys-na.net/Weather/v1/Weather?Location="+ data["GPS"][i]+"&Date=$in:" + data["iso"][i] + "&Provider=GLOBAL1&WeatherType=FORECAST_HOURLY&$fields=date,location,weatherCodes,cloudCover"
    headers={'Authorization':'Bearer '+bearer_token,'Accept':'application/json','Content-Type': 'application/json'}

    response = requests.request("GET", get_coverage_url, headers=headers)
    if response.status_code == 401:print('no access token, please recall the authentication API')
        
    res_coverage=response.json()
    
    for j in range(len(res_coverage)):    
        if (res_coverage != []):
            data_res={}
            data_res["location"]=data["location"][i]
            data_res["GPS"]=data["GPS"][i]
            data_res["date"]=res_coverage[j]['date']
            data_res["hour"]=data["hour"][i]
            data_res["satellite"]=data["satellite"][i]
            data_res["cloudCover"]=res_coverage[j]['cloudCover']['value']
            Image_date.append(data_res)
        
output_file=[]

for i in range(len(Image_date)):
    output_file.append({'location':Image_date[i]["location"]
                        ,'GPS':Image_date[i]["GPS"]
                        ,'date':Image_date[i]["date"]
                        ,'hour':Image_date[i]["hour"]
                        ,'satellite':Image_date[i]["satellite"]
                        ,'cloudCover':Image_date[i]["cloudCover"]
                                    })

output_file=pd.DataFrame(output_file) # create a Dataframe to save the results

# change date time format
date_final = pd.to_datetime(output_file.date)
output_file['date'] = date_final.dt.strftime('%Y-%m-%d')

# Save results in csv
output_file.to_csv(pa.join(path,'Weather_data_cloudcover_final.csv'),sep=';',index=False) 
Weather_data_cloudcover_final=output_file

# import datas
df = pd.read_csv(path+'/Weather_data_cloudcover_final.csv', sep = ';', names = ['location', 'GPS', 'date', 'hour', 'satellite', 'cloudcover'], header = 0)

# Function to map the 'Cloudcover' values to corresponding 'couleur' values
def map_cloudcover_to_color(value):
    if 0 <= value <= 20:
        return 'green'
    elif 20 < value <= 60:
        return 'yellow'
    elif 60 < value <= 80:
        return 'orange'
    elif 80 < value <= 100:
        return 'red'


# Apply the function to the 'Cloudcover' column and create a new 'couleur' column
df['color'] = df['cloudcover'].apply(map_cloudcover_to_color)

# Print the updated DataFrame
print(df)

# Export results in csv
df.to_csv(pa.join(path,'tab_with_color.csv'),sep=';',index=False)
# Out:
#                                               location  \
# 0    POLYGON ((-0.1242827114 51.41589769590001, 1.4...
# 1    POLYGON ((-0.1242827114 51.41589769590001, 1.4...
# 2    POLYGON ((-0.1242827114 51.41589769590001, 1.4...
# 3    POLYGON ((-0.1242827114 51.41589769590001, 1.4...
# 4    POLYGON ((-0.1242827114 51.41589769590001, 1.4...
# ..                                                 ...
# 320  POLYGON ((-2.846670030211575 55.19215016153343...
# 321  POLYGON ((-2.846670030211575 55.19215016153343...
# 322  POLYGON ((-2.846670030211575 55.19215016153343...
# 323  POLYGON ((-2.846670030211575 55.19215016153343...
# 324  POLYGON ((-2.846670030211575 55.19215016153343...
#
#                                                GPS        date      hour  \
# 0      POINT (0.535167013607956 51.15882388875995)  2025-03-01  11:17:00
# 1      POINT (0.535167013607956 51.15882388875995)  2025-03-01  11:17:00
# 2      POINT (0.535167013607956 51.15882388875995)  2025-03-03  11:06:00
# 3      POINT (0.535167013607956 51.15882388875995)  2025-03-06  11:16:00
# 4      POINT (0.535167013607956 51.15882388875995)  2025-03-08  11:06:00
# ..                                             ...         ...       ...
# 320  POINT (-3.071434834605655 55.035419648725096)  2025-03-02  11:35:00
# 321  POINT (-3.071434834605655 55.035419648725096)  2025-03-04  11:25:00
# 322  POINT (-3.071434834605655 55.035419648725096)  2025-03-04  11:26:00
# 323  POINT (-3.071434834605655 55.035419648725096)  2025-03-07  11:35:00
# 324  POINT (-3.071434834605655 55.035419648725096)  2025-03-07  11:36:00
#
#        satellite  cloudcover   color
# 0    Sentinel-2A        47.4  yellow
# 1    Sentinel-2C        47.4  yellow
# 2    Sentinel-2B        27.6  yellow
# 3    Sentinel-2B         0.3   green
# 4    Sentinel-2A        98.6     red
# ..           ...         ...     ...
# 320  Sentinel-2B        72.9  orange
# 321  Sentinel-2A        94.6     red
# 322  Sentinel-2C        94.6     red
# 323  Sentinel-2A        79.4  orange
# 324  Sentinel-2C        79.4  orange
#
# [325 rows x 7 columns]

# %% [markdown]
# ## 3️⃣ Outputs

# %% [markdown]
# ### Result rendering

# %%
# Load the data
data = df  # Replace with your DataFrame

# Convert 'location' into valid geometries
data["geometry"] = data["location"].apply(wkt.loads)

# Create a GeoDataFrame
gdf = gpd.GeoDataFrame(data, geometry="geometry", crs="EPSG:4326")

# Get unique dates
dates = gdf["date"].unique()

# Loop through each date, displaying one map per day
for date in dates:
    daily_gdf = gdf[gdf["date"] == date]

    # Group satellites by the first letter of their name
    daily_gdf['satellite_group'] = daily_gdf['satellite'].str[0]  # First letter of the satellite name

    # Get unique satellite groups
    satellite_groups = daily_gdf['satellite_group'].unique()

    # Loop through each satellite group for this day
    for group in satellite_groups:
        group_gdf = daily_gdf[daily_gdf['satellite_group'] == group]
        
        # Determine the group name
        group_name = "Sentinel_2" if group == "S" else "Landsat" if group == "L" else "Unknown"

        # Center the map
        center = [group_gdf.geometry.centroid.y.mean(), group_gdf.geometry.centroid.x.mean()]
        m = folium.Map(location=center, zoom_start=7, tiles="OpenStreetMap")

        # Add polygons with colored borders and transparency
        for _, row in group_gdf.iterrows():
            folium.GeoJson(
                row.geometry,
                style_function=lambda feature, color=row["color"]: {
                    "color": color,
                    "fillOpacity": 0.2,  # Transparency
                    "weight": 2  # Border thickness
                },
            ).add_to(m)

            # Compute centroid
            centroid = row.geometry.centroid
            folium.CircleMarker(
                location=[centroid.y, centroid.x],
                radius=5,
                color=row["color"],
                fill=True,
                fill_color=row["color"],
                fill_opacity=1
            ).add_to(m)

            # Add text for Satellite & Cloud Cover
            folium.Marker(
                location=[centroid.y + 0.1, centroid.x],  # Slightly above
                icon=folium.DivIcon(html=f'<div style="font-size: 10pt; color: black;">{row["satellite"]}</div>')
            ).add_to(m)

            folium.Marker(
                location=[centroid.y - 0.1, centroid.x],  # Slightly below
                icon=folium.DivIcon(html=f'<div style="font-size: 10pt; color: black;">{row["cloudcover"]}%</div>')
            ).add_to(m)

        # Save the map as an HTML file
        filename = f"map_{date}_group_{group_name}.html"
        m.save(filename)
        #print(f"Map saved: {filename}")

        # Display the map
        print(f"📅 **Map for {date} - {group_name}**")
        display(m)
# Out:
# C:\Users\mal\AppData\Local\anaconda3\envs\so-python\Lib\site-packages\geopandas\geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\mal\AppData\Local\Temp\ipykernel_1124\1149697618.py:31: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = [group_gdf.geometry.centroid.y.mean(), group_gdf.geometry.centroid.x.mean()]
# 📅 **Map for 2025-03-01 - Sentinel_2**
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77852d84dddd9d4bc9ef3709d78e753f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77852d84dddd9d4bc9ef3709d78e753f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77852d84dddd9d4bc9ef3709d78e753f = L.map(
#                 &quot;map_77852d84dddd9d4bc9ef3709d78e753f&quot;,
#                 {
#                     center: [52.460753624353664, -0.8601239502155155],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad9f5edade93ecd4f17214453aecb6c3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ad9f5edade93ecd4f17214453aecb6c3.addTo(map_77852d84dddd9d4bc9ef3709d78e753f);
#
#
#         function geo_json_63de26f870989ce3b77aec710c5e12d0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_63de26f870989ce3b77aec710c5e12d0_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_63de26f870989ce3b77aec710c5e12d0 = L.geoJson(null, {
#                 onEachFeature: geo_json_63de26f870989ce3b77aec710c5e12d0_onEachFeature,
#
#                 style: geo_json_63de26f870989ce3b77aec710c5e12d0_styler,
#         });
#
#         function geo_json_63de26f870989ce3b77aec710c5e12d0_add (data) {
#             geo_json_63de26f870989ce3b77aec710c5e12d0
#                 .addData(data);
#         }
#             geo_json_63de26f870989ce3b77aec710c5e12d0_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-0.1242827114, 51.41589769590001], [1.450589699, 51.3666020113], [1.4263753311990919, 51.11018468366207], [-0.1630345184036801, 50.781157544177205], [-0.1242827114, 51.41589769590001]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_63de26f870989ce3b77aec710c5e12d0.addTo(map_77852d84dddd9d4bc9ef3709d78e753f);
#
#
#             var circle_marker_04ccc629db9c30d8500cd8ad272533db = L.circleMarker(
#                 [51.15882388875995, 0.535167013607956],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_77852d84dddd9d4bc9ef3709d78e753f);
#
#
#             var marker_74bd1efcd41c0318df36f72590a18d41 = L.marker(
#                 [51.25882388875995, 0.535167013607956],
#                 {}
#             ).addTo(map_77852d84dddd9d4bc9ef3709d78e753f);
#
#
#             var div_icon_ad0ed7a451f89dcc4f9ccb4bc0a97807 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 10pt; color: black;\&quot;\u003eSentinel-2A\u003c/div\u003e&quot;});
#             marker_74bd1efcd41c0318df36f72590a18d41.setIcon(div_icon_ad0ed7a451f89dcc4f9ccb4bc0a97807);
#
#
#             var marker_b7d13d0fefd034b6ce97664b2aacfd48 = L.marker(
#                 [51.058823888759946, 0.535167013607956],
#                 {}
#             ).addTo(map_77852d84dddd9d4bc9ef3709d78e753f);
#
#
#             var div_icon_90ab1fc762363db09ea9f5011f04c14f = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 10pt; color: black;\&quot;\u003e47.4%\u003c/div\u003e&quot;});
#             marker_b7d13d0fefd034b6ce97664b2aacfd48.setIcon(div_icon_90ab1fc762363db09ea9f5011f04c14f);
#
#
#         function geo_json_8b02f95e760421608affcdd636b8227e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_8b02f95e760421608affcdd636b8227e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8b02f95e760421608affcdd636b8227e = L.geoJson(null, {
#                 onEachFeature: geo_json_8b02f95e760421608affcdd636b8227e_onEachFeature,
#
#                 style: geo_json_8b02f95e760421608affcdd636b8227e_styler,
#         });
#
#         function geo_json_8b02f95e760421608affcdd636b8227e_add (data) {
#             geo_json_8b02f95e760421608affcdd636b8227e
#                 .addData(data);
# C:\Users\mal\AppData\Local\Temp\ipykernel_1124\1149697618.py:31: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = [group_gdf.geometry.centroid.y.mean(), group_gdf.geometry.centroid.x.mean()]
# 📅 **Map for 2025-03-01 - Landsat**
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0eb9ecea14f65be0495fe590767ca814 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0eb9ecea14f65be0495fe590767ca814&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0eb9ecea14f65be0495fe590767ca814 = L.map(
#                 &quot;map_0eb9ecea14f65be0495fe590767ca814&quot;,
#                 {
#                     center: [52.69662747209173, -3.5605493691465275],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_00b58b615acaa6ac6a41f96da2283110 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_00b58b615acaa6ac6a41f96da2283110.addTo(map_0eb9ecea14f65be0495fe590767ca814);
#
#
#         function geo_json_d4ab0ac6c0abb76777d5b2efa02ac739_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_d4ab0ac6c0abb76777d5b2efa02ac739_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d4ab0ac6c0abb76777d5b2efa02ac739 = L.geoJson(null, {
#                 onEachFeature: geo_json_d4ab0ac6c0abb76777d5b2efa02ac739_onEachFeature,
#
#                 style: geo_json_d4ab0ac6c0abb76777d5b2efa02ac739_styler,
#         });
#
#         function geo_json_d4ab0ac6c0abb76777d5b2efa02ac739_add (data) {
#             geo_json_d4ab0ac6c0abb76777d5b2efa02ac739
#                 .addData(data);
#         }
#             geo_json_d4ab0ac6c0abb76777d5b2efa02ac739_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-5.544253905664104, 50.4984874090593], [-4.6342572365, 50.4703606298], [-4.666471643908035, 50.111392977500174], [-5.668945, 49.979488], [-5.544253905664104, 50.4984874090593]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_d4ab0ac6c0abb76777d5b2efa02ac739.addTo(map_0eb9ecea14f65be0495fe590767ca814);
#
#
#             var circle_marker_9953adf6b4f6603b69d3bea580cdde6a = L.circleMarker(
#                 [50.26092276842722, -5.1573372619809215],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0eb9ecea14f65be0495fe590767ca814);
#
#
#             var marker_fffde961f9d856a7aca07a5683075008 = L.marker(
#                 [50.36092276842722, -5.1573372619809215],
#                 {}
#             ).addTo(map_0eb9ecea14f65be0495fe590767ca814);
#
#
#             var div_icon_1d9c79c44fd6fdbe6fd06d7aee45d9a0 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 10pt; color: black;\&quot;\u003eLandsat-8\u003c/div\u003e&quot;});
#             marker_fffde961f9d856a7aca07a5683075008.setIcon(div_icon_1d9c79c44fd6fdbe6fd06d7aee45d9a0);
#
#
#             var marker_d55419e80ce9b1f677233fa65741e2b3 = L.marker(
#                 [50.16092276842722, -5.1573372619809215],
#                 {}
#             ).addTo(map_0eb9ecea14f65be0495fe590767ca814);
#
#
#             var div_icon_7a3c9335e85544344660d5fe2a1ba3cb = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 10pt; color: black;\&quot;\u003e16.8%\u003c/div\u003e&quot;});
#             marker_d55419e80ce9b1f677233fa65741e2b3.setIcon(div_icon_7a3c9335e85544344660d5fe2a1ba3cb);
#
#
#         function geo_json_95b45d1eb1f9be64ab812c0813b659a0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_95b45d1eb1f9be64ab812c0813b659a0_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_95b45d1eb1f9be64ab812c0813b659a0 = L.geoJson(null, {
#                 onEachFeature: geo_json_95b45d1eb1f9be64ab812c0813b659a0_onEachFeature,
#
#                 style: geo_json_95b45d1eb1f9be64ab812c0813b659a0_styler,
#         });
#
#         function geo_json_95b45d1eb1f9be64ab812c0813b659a0_add (data) {
#             geo_json_95b45d1eb1f9be64ab812c0813b659a0
#                 .addData(data);
#         }
# 📅 **Map for 2025-03-03 - Sentinel_2**
# C:\Users\mal\AppData\Local\anaconda3\envs\so-python\Lib\site-packages\geopandas\geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\mal\AppData\Local\Temp\ipykernel_1124\1149697618.py:31: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = [group_gdf.geometry.centroid.y.mean(), group_gdf.geometry.centroid.x.mean()]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db65b9ba8e31a3d95f853e041e949944 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db65b9ba8e31a3d95f853e041e949944&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db65b9ba8e31a3d95f853e041e949944 = L.map(
#                 &quot;map_db65b9ba8e31a3d95f853e041e949944&quot;,
#                 {
#                     center: [52.12929103340371, 0.5884114916298442],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1728c904439663e9cfc6891d5a77ebd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c1728c904439663e9cfc6891d5a77ebd.addTo(map_db65b9ba8e31a3d95f853e041e949944);
#
#
#         function geo_json_5506176344a489e2dc29fe60ab6c2b3b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_5506176344a489e2dc29fe60ab6c2b3b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_5506176344a489e2dc29fe60ab6c2b3b = L.geoJson(null, {
#                 onEachFeature: geo_json_5506176344a489e2dc29fe60ab6c2b3b_onEachFeature,
#
#                 style: geo_json_5506176344a489e2dc29fe60ab6c2b3b_styler,
#         });
#
#         function geo_json_5506176344a489e2dc29fe60ab6c2b3b_add (data) {
#             geo_json_5506176344a489e2dc29fe60ab6c2b3b
#                 .addData(data);
#         }
#             geo_json_5506176344a489e2dc29fe60ab6c2b3b_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-0.1242827114, 51.41589769590001], [1.450589699, 51.3666020113], [1.4263753311990919, 51.11018468366207], [-0.1630345184036801, 50.781157544177205], [-0.1242827114, 51.41589769590001]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_5506176344a489e2dc29fe60ab6c2b3b.addTo(map_db65b9ba8e31a3d95f853e041e949944);
#
#
#             var circle_marker_64af844a1e78f018d1532c7dac695af3 = L.circleMarker(
#                 [51.15882388875995, 0.535167013607956],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_db65b9ba8e31a3d95f853e041e949944);
#
#
#             var marker_4ebcb25cf33671f27058c6ae86c41acd = L.marker(
#                 [51.25882388875995, 0.535167013607956],
#                 {}
#             ).addTo(map_db65b9ba8e31a3d95f853e041e949944);
#
#
#             var div_icon_b763b99d92449968f63270c3dc6eec19 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 10pt; color: black;\&quot;\u003eSentinel-2B\u003c/div\u003e&quot;});
#             marker_4ebcb25cf33671f27058c6ae86c41acd.setIcon(div_icon_b763b99d92449968f63270c3dc6eec19);
#
#
#             var marker_3a010d7a1aec604235ce1a379de7d9d6 = L.marker(
#                 [51.058823888759946, 0.535167013607956],
#                 {}
#             ).addTo(map_db65b9ba8e31a3d95f853e041e949944);
#
#
#             var div_icon_2f0e58bcce0ed3e3e42dad1983c80a94 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 10pt; color: black;\&quot;\u003e27.6%\u003c/div\u003e&quot;});
#             marker_3a010d7a1aec604235ce1a379de7d9d6.setIcon(div_icon_2f0e58bcce0ed3e3e42dad1983c80a94);
#
#
#         function geo_json_879f47b69866451de5ade58213bb3b6b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_879f47b69866451de5ade58213bb3b6b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_879f47b69866451de5ade58213bb3b6b = L.geoJson(null, {
#                 onEachFeature: geo_json_879f47b69866451de5ade58213bb3b6b_onEachFeature,
#
#                 style: geo_json_879f47b69866451de5ade58213bb3b6b_styler,
#         });
#
#         function geo_json_879f47b69866451de5ade58213bb3b6b_add (data) {
#             geo_json_879f47b69866451de5ade58213bb3b6b
#                 .addData(data);
# C:\Users\mal\AppData\Local\anaconda3\envs\so-python\Lib\site-packages\geopandas\geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\mal\AppData\Local\Temp\ipykernel_1124\1149697618.py:31: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = [group_gdf.geometry.centroid.y.mean(), group_gdf.geometry.centroid.x.mean()]
# 📅 **Map for 2025-03-06 - Sentinel_2**
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a6bdb53ce293056d0a0971a1c2fd091 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a6bdb53ce293056d0a0971a1c2fd091&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a6bdb53ce293056d0a0971a1c2fd091 = L.map(
#                 &quot;map_0a6bdb53ce293056d0a0971a1c2fd091&quot;,
#                 {
#                     center: [52.460753624353664, -0.8601239502155152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7cd70a5c9227717f3d1720168e4e34bd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7cd70a5c9227717f3d1720168e4e34bd.addTo(map_0a6bdb53ce293056d0a0971a1c2fd091);
#
#
#         function geo_json_958ffc36b411ba9813a0f5dfe66649ac_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_958ffc36b411ba9813a0f5dfe66649ac_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_958ffc36b411ba9813a0f5dfe66649ac = L.geoJson(null, {
#                 onEachFeature: geo_json_958ffc36b411ba9813a0f5dfe66649ac_onEachFeature,
#
#                 style: geo_json_958ffc36b411ba9813a0f5dfe66649ac_styler,
#         });
#
#         function geo_json_958ffc36b411ba9813a0f5dfe66649ac_add (data) {
#             geo_json_958ffc36b411ba9813a0f5dfe66649ac
#                 .addData(data);
#         }
#             geo_json_958ffc36b411ba9813a0f5dfe66649ac_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-0.1242827114, 51.41589769590001], [1.450589699, 51.3666020113], [1.4263753311990919, 51.11018468366207], [-0.1630345184036801, 50.781157544177205], [-0.1242827114, 51.41589769590001]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_958ffc36b411ba9813a0f5dfe66649ac.addTo(map_0a6bdb53ce293056d0a0971a1c2fd091);
#
#
#             var circle_marker_70bc7c78abf3e76e2c84e78ecf2553b5 = L.circleMarker(
#                 [51.15882388875995, 0.535167013607956],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0a6bdb53ce293056d0a0971a1c2fd091);
#
#
#             var marker_c2d7af027a912da0d69414dd27937215 = L.marker(
#                 [51.25882388875995, 0.535167013607956],
#                 {}
#             ).addTo(map_0a6bdb53ce293056d0a0971a1c2fd091);
#
#
#             var div_icon_026ad08af17fad2b04bae705fbafa53b = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 10pt; color: black;\&quot;\u003eSentinel-2B\u003c/div\u003e&quot;});
#             marker_c2d7af027a912da0d69414dd27937215.setIcon(div_icon_026ad08af17fad2b04bae705fbafa53b);
#
#
#             var marker_f24d7028dc16c2a782556231dba88d08 = L.marker(
#                 [51.058823888759946, 0.535167013607956],
#                 {}
#             ).addTo(map_0a6bdb53ce293056d0a0971a1c2fd091);
#
#
#             var div_icon_1eb93932ed202317488764b967b3502f = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 10pt; color: black;\&quot;\u003e0.3%\u003c/div\u003e&quot;});
#             marker_f24d7028dc16c2a782556231dba88d08.setIcon(div_icon_1eb93932ed202317488764b967b3502f);
#
#
#         function geo_json_d25639fa6fe136d4b752c10b32695a03_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_d25639fa6fe136d4b752c10b32695a03_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d25639fa6fe136d4b752c10b32695a03 = L.geoJson(null, {
#                 onEachFeature: geo_json_d25639fa6fe136d4b752c10b32695a03_onEachFeature,
#
#                 style: geo_json_d25639fa6fe136d4b752c10b32695a03_styler,
#         });
#
#         function geo_json_d25639fa6fe136d4b752c10b32695a03_add (data) {
#             geo_json_d25639fa6fe136d4b752c10b32695a03
#                 .addData(data);
#         }
# C:\Users\mal\AppData\Local\anaconda3\envs\so-python\Lib\site-packages\geopandas\geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\mal\AppData\Local\Temp\ipykernel_1124\1149697618.py:31: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = [group_gdf.geometry.centroid.y.mean(), group_gdf.geometry.centroid.x.mean()]
# 📅 **Map for 2025-03-08 - Sentinel_2**
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_90ff7b3ae408fbe04adb0974b569a9d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_90ff7b3ae408fbe04adb0974b569a9d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_90ff7b3ae408fbe04adb0974b569a9d4 = L.map(
#                 &quot;map_90ff7b3ae408fbe04adb0974b569a9d4&quot;,
#                 {
#                     center: [52.12929103340371, 0.5884114916298443],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a318cc0d25302393edf024035af80fbc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a318cc0d25302393edf024035af80fbc.addTo(map_90ff7b3ae408fbe04adb0974b569a9d4);
#
#
#         function geo_json_10fe90b0bb448ed4f00750e4478c733a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_10fe90b0bb448ed4f00750e4478c733a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_10fe90b0bb448ed4f00750e4478c733a = L.geoJson(null, {
#                 onEachFeature: geo_json_10fe90b0bb448ed4f00750e4478c733a_onEachFeature,
#
#                 style: geo_json_10fe90b0bb448ed4f00750e4478c733a_styler,
#         });
#
#         function geo_json_10fe90b0bb448ed4f00750e4478c733a_add (data) {
#             geo_json_10fe90b0bb448ed4f00750e4478c733a
#                 .addData(data);
#         }
#             geo_json_10fe90b0bb448ed4f00750e4478c733a_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-0.1242827114, 51.41589769590001], [1.450589699, 51.3666020113], [1.4263753311990919, 51.11018468366207], [-0.1630345184036801, 50.781157544177205], [-0.1242827114, 51.41589769590001]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_10fe90b0bb448ed4f00750e4478c733a.addTo(map_90ff7b3ae408fbe04adb0974b569a9d4);
#
#
#             var circle_marker_56729bfaa66002b38fc8901be5a86141 = L.circleMarker(
#                 [51.15882388875995, 0.535167013607956],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_90ff7b3ae408fbe04adb0974b569a9d4);
#
#
#             var marker_7525f17a32a62319260ea1ac67fe4e65 = L.marker(
#                 [51.25882388875995, 0.535167013607956],
#                 {}
#             ).addTo(map_90ff7b3ae408fbe04adb0974b569a9d4);
#
#
#             var div_icon_7ee85759defc18e245bf363096f51b03 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 10pt; color: black;\&quot;\u003eSentinel-2A\u003c/div\u003e&quot;});
#             marker_7525f17a32a62319260ea1ac67fe4e65.setIcon(div_icon_7ee85759defc18e245bf363096f51b03);
#
#
#             var marker_55139709d306e6cb88e225bfb6e60477 = L.marker(
#                 [51.058823888759946, 0.535167013607956],
#                 {}
#             ).addTo(map_90ff7b3ae408fbe04adb0974b569a9d4);
#
#
#             var div_icon_f6fc675df6b59e562dff614cd3058ad5 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 10pt; color: black;\&quot;\u003e98.6%\u003c/div\u003e&quot;});
#             marker_55139709d306e6cb88e225bfb6e60477.setIcon(div_icon_f6fc675df6b59e562dff614cd3058ad5);
#
#
#         function geo_json_5be2abd319b4df605b93489d197211c6_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_5be2abd319b4df605b93489d197211c6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_5be2abd319b4df605b93489d197211c6 = L.geoJson(null, {
#                 onEachFeature: geo_json_5be2abd319b4df605b93489d197211c6_onEachFeature,
#
#                 style: geo_json_5be2abd319b4df605b93489d197211c6_styler,
#         });
#
#         function geo_json_5be2abd319b4df605b93489d197211c6_add (data) {
#             geo_json_5be2abd319b4df605b93489d197211c6
#                 .addData(data);
#         }
# C:\Users\mal\AppData\Local\anaconda3\envs\so-python\Lib\site-packages\geopandas\geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\mal\AppData\Local\Temp\ipykernel_1124\1149697618.py:31: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = [group_gdf.geometry.centroid.y.mean(), group_gdf.geometry.centroid.x.mean()]
# 📅 **Map for 2025-03-04 - Sentinel_2**
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_044a36d14755dbe7e9aca39f8bf80792 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_044a36d14755dbe7e9aca39f8bf80792&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_044a36d14755dbe7e9aca39f8bf80792 = L.map(
#                 &quot;map_044a36d14755dbe7e9aca39f8bf80792&quot;,
#                 {
#                     center: [52.62783515372238, -2.8080265046780917],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b207dedb7aca4bceb66027a15a41928 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
# ...
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ecc329fda318b951c811c73f7f0ed6d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ecc329fda318b951c811c73f7f0ed6d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ecc329fda318b951c811c73f7f0ed6d = L.map(
#                 &quot;map_1ecc329fda318b951c811c73f7f0ed6d&quot;,
#                 {
#                     center: [52.68093929829766, -4.101745747733787],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1bb6e4fa7411356c5a90c97dd1db5555 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1bb6e4fa7411356c5a90c97dd1db5555.addTo(map_1ecc329fda318b951c811c73f7f0ed6d);
#
#
#         function geo_json_c0eaf16d1cd121a5504f5e05ca4b3517_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_c0eaf16d1cd121a5504f5e05ca4b3517_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c0eaf16d1cd121a5504f5e05ca4b3517 = L.geoJson(null, {
#                 onEachFeature: geo_json_c0eaf16d1cd121a5504f5e05ca4b3517_onEachFeature,
#
#                 style: geo_json_c0eaf16d1cd121a5504f5e05ca4b3517_styler,
#         });
#
#         function geo_json_c0eaf16d1cd121a5504f5e05ca4b3517_add (data) {
#             geo_json_c0eaf16d1cd121a5504f5e05ca4b3517
#                 .addData(data);
#         }
#             geo_json_c0eaf16d1cd121a5504f5e05ca4b3517_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-5.544253905664104, 50.4984874090593], [-4.6342572365, 50.4703606298], [-4.666471643908035, 50.111392977500174], [-5.668945, 49.979488], [-5.544253905664104, 50.4984874090593]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_c0eaf16d1cd121a5504f5e05ca4b3517.addTo(map_1ecc329fda318b951c811c73f7f0ed6d);
#
#
#             var circle_marker_1fbf94721e9860037383d7f22a345c77 = L.circleMarker(
#                 [50.26092276842722, -5.1573372619809215],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1ecc329fda318b951c811c73f7f0ed6d);
#
#
#             var marker_94152b6fcc892133e315bfe76ef7a5e6 = L.marker(
#                 [50.36092276842722, -5.1573372619809215],
#                 {}
#             ).addTo(map_1ecc329fda318b951c811c73f7f0ed6d);
#
#
#             var div_icon_d4cdb87abae2bf4f2ea9eec111a7462b = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 10pt; color: black;\&quot;\u003eLandsat-9\u003c/div\u003e&quot;});
#             marker_94152b6fcc892133e315bfe76ef7a5e6.setIcon(div_icon_d4cdb87abae2bf4f2ea9eec111a7462b);
#
#
#             var marker_37554f5dabfc2f04bf7c28ce1ef7d19b = L.marker(
#                 [50.16092276842722, -5.1573372619809215],
#                 {}
#             ).addTo(map_1ecc329fda318b951c811c73f7f0ed6d);
#
#
#             var div_icon_ebd24de23e62ac262823c5da80a5b74b = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 10pt; color: black;\&quot;\u003e13.2%\u003c/div\u003e&quot;});
#             marker_37554f5dabfc2f04bf7c28ce1ef7d19b.setIcon(div_icon_ebd24de23e62ac262823c5da80a5b74b);
#
#
#         function geo_json_05e16d29cdca37cad90f2481bf196e76_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_05e16d29cdca37cad90f2481bf196e76_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_05e16d29cdca37cad90f2481bf196e76 = L.geoJson(null, {
#                 onEachFeature: geo_json_05e16d29cdca37cad90f2481bf196e76_onEachFeature,
#
#                 style: geo_json_05e16d29cdca37cad90f2481bf196e76_styler,
#         });
#
#         function geo_json_05e16d29cdca37cad90f2481bf196e76_add (data) {
#             geo_json_05e16d29cdca37cad90f2481bf196e76
#                 .addData(data);
#         }
# C:\Users\mal\AppData\Local\anaconda3\envs\so-python\Lib\site-packages\geopandas\geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\mal\AppData\Local\Temp\ipykernel_1124\1149697618.py:31: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = [group_gdf.geometry.centroid.y.mean(), group_gdf.geometry.centroid.x.mean()]
# 📅 **Map for 2025-03-07 - Sentinel_2**
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7a38652c8d4ed75f89c99c0b435c011 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7a38652c8d4ed75f89c99c0b435c011&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b7a38652c8d4ed75f89c99c0b435c011 = L.map(
#                 &quot;map_b7a38652c8d4ed75f89c99c0b435c011&quot;,
#                 {
#                     center: [52.62423797946242, -3.9094208712854597],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f195288962d975b77097a57646d28580 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f195288962d975b77097a57646d28580.addTo(map_b7a38652c8d4ed75f89c99c0b435c011);
#
#
#         function geo_json_d518f82d2bff0395c9c1d05e824ec2a0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_d518f82d2bff0395c9c1d05e824ec2a0_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d518f82d2bff0395c9c1d05e824ec2a0 = L.geoJson(null, {
#                 onEachFeature: geo_json_d518f82d2bff0395c9c1d05e824ec2a0_onEachFeature,
#
#                 style: geo_json_d518f82d2bff0395c9c1d05e824ec2a0_styler,
#         });
#
#         function geo_json_d518f82d2bff0395c9c1d05e824ec2a0_add (data) {
#             geo_json_d518f82d2bff0395c9c1d05e824ec2a0
#                 .addData(data);
#         }
#             geo_json_d518f82d2bff0395c9c1d05e824ec2a0_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-5.544253905664104, 50.4984874090593], [-4.6342572365, 50.4703606298], [-4.666471643908035, 50.111392977500174], [-5.668945, 49.979488], [-5.544253905664104, 50.4984874090593]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_d518f82d2bff0395c9c1d05e824ec2a0.addTo(map_b7a38652c8d4ed75f89c99c0b435c011);
#
#
#             var circle_marker_b4cd8cbdcce05aab958a71713a18f828 = L.circleMarker(
#                 [50.26092276842722, -5.1573372619809215],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b7a38652c8d4ed75f89c99c0b435c011);
#
#
#             var marker_bf5832b915b31d612047005dd3b6fb82 = L.marker(
#                 [50.36092276842722, -5.1573372619809215],
#                 {}
#             ).addTo(map_b7a38652c8d4ed75f89c99c0b435c011);
#
#
#             var div_icon_1468edec1bac8f77d807d9093c664b57 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 10pt; color: black;\&quot;\u003eSentinel-2A\u003c/div\u003e&quot;});
#             marker_bf5832b915b31d612047005dd3b6fb82.setIcon(div_icon_1468edec1bac8f77d807d9093c664b57);
#
#
#             var marker_a7a3c5519d67ddb15592457b5fdaf98d = L.marker(
#                 [50.16092276842722, -5.1573372619809215],
#                 {}
#             ).addTo(map_b7a38652c8d4ed75f89c99c0b435c011);
#
#
#             var div_icon_aff69e7270d614c31e1709a4f47de311 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 10pt; color: black;\&quot;\u003e41.9%\u003c/div\u003e&quot;});
#             marker_a7a3c5519d67ddb15592457b5fdaf98d.setIcon(div_icon_aff69e7270d614c31e1709a4f47de311);
#
#
#         function geo_json_7c57356933b8a2a49906e69e97ea97db_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_7c57356933b8a2a49906e69e97ea97db_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7c57356933b8a2a49906e69e97ea97db = L.geoJson(null, {
#                 onEachFeature: geo_json_7c57356933b8a2a49906e69e97ea97db_onEachFeature,
#
#                 style: geo_json_7c57356933b8a2a49906e69e97ea97db_styler,
#         });
#
#         function geo_json_7c57356933b8a2a49906e69e97ea97db_add (data) {
#             geo_json_7c57356933b8a2a49906e69e97ea97db
#                 .addData(data);
#         }
